# %%
import pandas as pd
import geopandas as gpd
from os.path import join
from os.path import join
from os import getcwd

pd.set_option('display.max_columns', None)

my_dir = getcwd()
shapefile = 'LAD_MAY_2024_UK_BFC.shp'
LAD_dir = 'Local_Authority_Districts_May_2024_Boundaries_UK_BFC_729848500717969389'


gdf = gpd.read_file(join(my_dir,LAD_dir,shapefile))
gdf.head()
# gdf.shape
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File fiona\\ogrext.pyx:136, in fiona.ogrext.gdal_open_vector()
#
# File fiona\\_err.pyx:291, in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: C:\Users\ondra\Local_Authority_Districts_May_2024_Boundaries_UK_BFC_729848500717969389\LAD_MAY_2024_UK_BFC.shp: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# Cell In[402], line 13
#       9 shapefile = 'LAD_MAY_2024_UK_BFC.shp'
#      10 LAD_dir = 'Local_Authority_Districts_May_2024_Boundaries_UK_BFC_729848500717969389'
# ---> 13 gdf = gpd.read_file(join(my_dir,LAD_dir,shapefile))
#      14 gdf.head()
#
# File ~\anaconda3\Lib\site-packages\geopandas\io\file.py:297, in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     294     else:
# ...

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable

# fig, ax = plt.subplots(1,1)
# gdf.plot(ax = ax, column = 'LONG')
# ax.set_axis_off()
# plt.show()

region_lookup_file = r'C:\Users\ondra\Downloads\ONS_project\LA_region_lookup.csv'
region_df = pd.read_csv(region_lookup_file)
region_df.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[392], line 12
#       6 # fig, ax = plt.subplots(1,1)
#       7 # gdf.plot(ax = ax, column = 'LONG')
#       8 # ax.set_axis_off()
#       9 # plt.show()
#      11 region_lookup_file = r'C:\Users\ondra\Downloads\ONS_project\LA_region_lookup.csv'
# ---> 12 region_df = pd.read_csv(region_lookup_file)
#      13 region_df.head()
#
# ...

# %%
import numpy as np

et_file = r'C:\Users\ondra\Downloads\ONS_project\Ethnicity_data.txt'
et_df = pd.read_csv(et_file, sep='\t', decimal=',')

et_df = et_df.loc[:,['Area name','White: English, Welsh, Scottish, Northern Irish or British\n(percent)', 'White: Irish\n(percent)','White: Gypsy or Irish Traveller\n(percent)','White: Roma\n(percent)','White: Other White\n(percent)']]
et_df['Whiteness'] = et_df.iloc[:,1:].sum(axis=1)

et_df = et_df.loc[:,['Area name','Whiteness']]
et_df.rename(columns={'Area name':'LAD24NM'}, inplace = True)
# Out:
#                 LAD24NM  Whiteness
# 0            Hartlepool       96.4
# 1         Middlesbrough       82.3
# 2  Redcar and Cleveland       97.7
# 3      Stockton0on0Tees       92.1
# 4            Darlington       94.4

# %%
# gdf = gdf.merge(et_df, on = 'LAD24NM')
# gdf.shape
# gdf.head()

# %%
fig, ax = plt.subplots(1,1)
gdf.plot(ax = ax, column = 'Ethnicity', cmap = 'gray',vmin = 0, vmax = 100, edgecolor='black', linewidth=0.3)
ax.axis('off')
plt.suptitle('Whiteness of England and Wales')
# plt.savefig(r'C:\Users\ondra\Downloads\ONS_project\Whiteness.jpg')
plt.show()

# %%
et_df.sort_values(by = 'Whiteness', inplace=True)
et_df.head()
# Out:
#        LAD24NM  Whiteness
# 300     Newham       30.8
# 280      Brent       34.6
# 301  Redbridge       34.9
# 36      Slough       35.9
# 290     Harrow       36.4

# %%
from os.path import join
from os import getcwd

my_dir = getcwd()
shapefile = 'LAD_MAY_2024_UK_BFC.shp'
LAD_dir = 'Local_Authority_Districts_May_2024_Boundaries_UK_BFC_729848500717969389'
print(join(my_dir,LAD_dir,shapefile))
# Out:
# C:\Users\ondra\Local_Authority_Districts_May_2024_Boundaries_UK_BFC_729848500717969389\LAD_MAY_2024_UK_BFC.shp
